# %%
import pandas as pd
import numpy as np
pd.set_option=('display.max_columns', None)
machine_data = pd.read_csv('https://drive.google.com/file/d/1-vX7qbPd__MkyFO4Ud0iItufEO6fIHot/view?usp=sharing')
print("data set telah dibaca")
# Out:
# data set telah dibaca

# %%
machine_data.shape
# Out:
# (209, 10)

# %%
machine_data
# Out:
#     vendor_name       model_name  MYCT   MMIN   MMAX  CACH  CHMIN  CHMAX  \
# 0       adviser            32/60   125    256   6000   256     16    128
# 1        amdahl           470v/7    29   8000  32000    32      8     32
# 2        amdahl          470v/7a    29   8000  32000    32      8     32
# 3        amdahl          470v/7b    29   8000  32000    32      8     32
# 4        amdahl          470v/7c    29   8000  16000    32      8     16
# 5        amdahl           470v/b    26   8000  32000    64      8     32
# 6        amdahl         580-5840    23  16000  32000    64     16     32
# 7        amdahl         580-5850    23  16000  32000    64     16     32
# 8        amdahl         580-5860    23  16000  64000    64     16     32
# 9        amdahl         580-5880    23  32000  64000   128     32     64
# 10       apollo            dn320   400   1000   3000     0      1      2
# 11       apollo            dn420   400    512   3500     4      1      6
# ...

# %%
vendor_counts = machine_data['vendor_name'].value_counts()
vendor_counts
# Out:
# ibm             32
# nas             19
# sperry          13
# honeywell       13
# ncr             13
# siemens         12
# cdc              9
# amdahl           9
# burroughs        8
# harris           7
# dg               7
# hp               7
# dec              6
# c.r.d            6
# magnuson         6
# ipl              6
# formation        5
# cambex           5
# prime            5
# gould            3
# nixdorf          3
# perkin-elmer     3
# bti              2
# basf             2
# apollo           2
# wang             2
# sratus           1
# adviser          1
# four-phase       1
# microdata        1
# Name: vendor_name, dtype: int64

# %%
vendor = machine_data.groupby("vendor_name").mean()
vendor.head()
# Out:
#               MYCT          MMIN          MMAX        CACH      CHMIN  \
# vendor_name
# adviser      125.0    256.000000   6000.000000  256.000000  16.000000
# amdahl        26.0  13333.333333  37333.333333   56.888889  13.333333
# apollo       400.0    756.000000   3250.000000    2.000000   1.000000
# basf          55.0   3000.000000  12000.000000   65.000000   1.000000
# bti          275.0    288.000000   8032.000000    0.000000   2.500000
#
#                   CHMAX         PRP         ERP
# vendor_name
# adviser      128.000000  198.000000  199.000000
# amdahl        33.777778  416.333333  436.666667
# apollo         4.000000   39.000000   23.500000
# basf           8.000000  115.000000   93.500000
# bti           18.000000   22.500000   39.500000

# %%
desc = machine_data.corr()
desc.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
#            MYCT      MMIN      MMAX      CACH     CHMIN     CHMAX       PRP  \
# MYCT   1.000000 -0.335642 -0.378561 -0.321000 -0.301090 -0.250502 -0.307099
# MMIN  -0.335642  1.000000  0.758157  0.534729  0.517189  0.266907  0.794931
# MMAX  -0.378561  0.758157  1.000000  0.537990  0.560513  0.527246  0.863004
# CACH  -0.321000  0.534729  0.537990  1.000000  0.582245  0.487846  0.662641
# CHMIN -0.301090  0.517189  0.560513  0.582245  1.000000  0.548281  0.608903
# CHMAX -0.250502  0.266907  0.527246  0.487846  0.548281  1.000000  0.605209
# PRP   -0.307099  0.794931  0.863004  0.662641  0.608903  0.605209  1.000000
# ERP   -0.288396  0.819292  0.901202  0.648620  0.610580  0.592156  0.966472
#
#             ERP
# MYCT  -0.288396
# MMIN   0.819292
# MMAX   0.901202
# CACH   0.648620
# CHMIN  0.610580
# CHMAX  0.592156
# PRP    0.966472
# ERP    1.000000

# %%
desc = machine_data.describe()
desc.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_93fb4f02_a895_11e9_be40_b8763f5d28aarow0_col0 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_93fb4f02_a895_11e9_be40_b8763f5d28aarow0_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_93fb4f02_a895_11e9_be40_b8763f5d28aarow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_93fb4f02_a895_11e9_be40_b8763f5d28aarow0_col3 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_93fb4f02_a895_11e9_be40_b8763f5d28aarow0_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_93fb4f02_a895_11e9_be40_b8763f5d28aarow0_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_93fb4f02_a895_11e9_be40_b8763f5d28aarow0_col6 {
#             background-color:  #7396f5;
#             color:  #000000;
# ...

# %%
import pandas as pd
import numpy as np

corr = machine_data.corr()
corr.style.background_gradient(cmap='coolwarm', axis=None).set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_4da4c6c6_a895_11e9_9fc6_b8763f5d28aarow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4da4c6c6_a895_11e9_9fc6_b8763f5d28aarow0_col1 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_4da4c6c6_a895_11e9_9fc6_b8763f5d28aarow0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4da4c6c6_a895_11e9_9fc6_b8763f5d28aarow0_col3 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_4da4c6c6_a895_11e9_9fc6_b8763f5d28aarow0_col4 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_4da4c6c6_a895_11e9_9fc6_b8763f5d28aarow0_col5 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_4da4c6c6_a895_11e9_9fc6_b8763f5d28aarow0_col6 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
# ...

# %%
import matplotlib.pyplot as plt
# matplotlib histogram
plt.hist(machine_data['MYCT'], color = 'blue', edgecolor = 'black',)

# %%
import seaborn as sns
sns.distplot(machine_data['MYCT'], hist=True, kde=False, 
             bins=int(180/5), color = 'blue',
             hist_kws={'edgecolor':'black'})

# %%
import seaborn as sns
corr = machine_data.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)
